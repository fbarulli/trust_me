# %%
import pandas as pd
dataframe = pd.read_csv("categories.csv")
display(dataframe)
# Out:
#                  Category Name
# 0                 animals_pets
# 1             beauty_wellbeing
# 2            business_services
# 3   construction_manufactoring
# 4           education_training
# 5       electronics_technology
# 6         events_entertainment
# 7       food_beverages_tobacco
# 8               health_medical
# 9               hobbies_crafts
# 10                 home_garden
# 11               home_services
# 12   legal_services_government
# 13            media_publishing
# 14             money_insurance
# 15       public_local_services
# 16            restaurants_bars
# 17            shopping_fashion
# 18                      sports
# 19             travel_vacation
# 20                   utilities
# 21     vehicles_transportation

# %%
import pandas as pd
dataframe_2 = pd.read_csv("final_output.csv")

df_cleaned = dataframe_2.dropna(subset=["Company Name", "Trust Score", "Number of Reviews"])
display(df_cleaned)
# Out:
#                      Category                         Company Name  \
# 0                animals_pets                Boomerang Pet ID Tags
# 1                animals_pets                         TadiBrothers
# 3                animals_pets               Springtime Supplements
# 4                animals_pets                   Bluegrass Hemp Oil
# 5                animals_pets                            PopArtYou
# ...                       ...                                  ...
# 1586  vehicles_transportation            Bike Shed Motorcycle Club
# 1587  vehicles_transportation  Trailer Decking Supplies & Services
# 1588  vehicles_transportation                       Flatbike, Inc.
# 1589  vehicles_transportation             Hamilton Power Solutions
# 1591  vehicles_transportation                           Gofastpass
#
#       Trust Score  Number of Reviews             Company Country  \
# 0             4.9            11822.0  Pismo Beach, United States
# ...

# %%
import matplotlib.pyplot as plt

# 1. Distribution of Trust Scores
plt.figure(figsize=(8, 5))
plt.hist(df_cleaned['Trust Score'], bins=30, edgecolor='black')
plt.title('Distribution of Trust Scores')
plt.xlabel('Trust Score')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
# 2. Number of Reviews per Company (Top 10 Companies by Number of Reviews)
top_10_reviews = df_cleaned.nlargest(10, 'Number of Reviews')
plt.figure(figsize=(10, 6))
plt.barh(top_10_reviews['Company Name'], top_10_reviews['Number of Reviews'], color='skyblue')
plt.title('Top 10 Companies by Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Company Name')
plt.gca().invert_yaxis()
plt.show()

# %%
# 3. Scatter Plot: Trust Score vs. Number of Reviews
plt.figure(figsize=(8, 5))
plt.scatter(df_cleaned['Number of Reviews'], df_cleaned['Trust Score'], alpha=0.7)
plt.title('Trust Score vs. Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Trust Score')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

numeric_df = df_cleaned.select_dtypes(include=['number'])

# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
